# %%
import os 
os.environ["OPENAI_API_KEY"] = "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"
from langchain.llms import OpenAI
llm = OpenAI(temperature = 0.9)
text = "输入中国人最喜欢的六种水果"
print(llm(text))
# Out:
# 1. 苹果
# 2. 橘子
# 3. 香蕉
# 4. 梨
# 5. 葡萄
# 6. 桃子

# %%
from langchain.prompts import PromptTemplate

# %%
prompt = PromptTemplate(
    input_variables=["food"],
    template="中国人爱吃的6种{food}？"
)

# %%
from langchain import ConversationChain

# %%
llm = OpenAI(temperature = 0.9)
conversation = ConversationChain(llm = llm, verbose = True)

# %%
conversation.predict(input = "战鹰战鹰你几岁啦")
# Out:
# > Entering new ConversationChain chain...
# Prompt after formatting:
# The following is a friendly conversation between a human and an AI. The AI is talkative and provides lots of specific details from its context. If the AI does not know the answer to a question, it truthfully says it does not know.
#
# Current conversation:
#
# Human: 战鹰战鹰你几岁啦
# AI:
#
# > Finished chain.
# ' 我现在只有四个月大。我最近在学习新的东西，如何有效地理解人类语言和指令，以便更好地为您服务。'

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunksize = 1000, chunk_overlap = 0)
split_docs = text_splitter.split_documents(docs)
from langchain.vectorstores import Pinecone
from langchain.embeddings.openai import OpenAIEmbeddings
import pinecone
OPENAI_API_KEY = "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"
from langchain.llms import OpenAI
from langchain.chains.summarize import load_summarize_chain
llm = OpenAI(temperture=0, openai_api_key = OPENAI_API_KEY)
chain = load_summarize_chain(llm,chain_type="map_reduce",verbose=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 from langchain.text_splitter import RecursiveCharacterTextSplitter
# ----> 2 text_splitter = RecursiveCharacterTextSplitter(chunksize = 1000, chunk_overlap = 0)
#       3 split_docs = text_splitter.split_documents(docs)
#       4 from langchain.vectorstores import Pinecone
#
# File c:\Users\SEU\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\text_splitter.py:277, in RecursiveCharacterTextSplitter.__init__(self, separators, **kwargs)
#     275 def __init__(self, separators: Optional[List[str]] = None, **kwargs: Any):
#     276     """Create a new TextSplitter."""
# --> 277     super().__init__(**kwargs)
#     278     self._separators = separators or ["\n\n", "\n", " ", ""]
#
# TypeError: TextSplitter.__init__() got an unexpected keyword argument 'chunksize'

# %%
with open('D:/23spring/AD-GPT/workplace/news_1'+ "/text.txt", "r", encoding='utf8') as f:
    texts = f.read()
    print(doc)
OPENAI_API_KEY = "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"
from langchain.llms import OpenAI
from langchain.chains.summarize import load_summarize_chain
llm = OpenAI(temperture=0, openai_api_key = OPENAI_API_KEY)
chain = load_summarize_chain(llm,chain_type="map_reduce",verbose=True)
from langchain.docstore.document import Document
docs = [Document(page_content=t) for t in texts[:3]]
chain.run(input_documents = docs)
# Out:
# WARNING! temperture is not default parameter.
#                     temperture was transferred to model_kwargs.
#                     Please confirm that temperture is what you intended.
# ...

# %%
import os 

def find_files(path, A):
    results = []
    for root, _, files in os.walk(path):
        for name in files:
            if name == A+'.txt':
                results.append(os.path.join(root,name))
    return results

files = find_files('D:\\23spring\\AD-GPT\\workplace\\','places')
print(files)
# Out:
# ['D:\\23spring\\AD-GPT\\workplace\\5_29_news_data\\AA\\news_1\\places.txt', 'D:\\23spring\\AD-GPT\\workplace\\5_29_news_data\\AA\\news_10\\places.txt', 'D:\\23spring\\AD-GPT\\workplace\\5_29_news_data\\AA\\news_11\\places.txt', 'D:\\23spring\\AD-GPT\\workplace\\5_29_news_data\\AA\\news_12\\places.txt', 'D:\\23spring\\AD-GPT\\workplace\\5_29_news_data\\AA\\news_13\\places.txt', 'D:\\23spring\\AD-GPT\\workplace\\5_29_news_data\\AA\\news_14\\places.txt', 'D:\\23spring\\AD-GPT\\workplace\\5_29_news_data\\AA\\news_15\\places.txt', 'D:\\23spring\\AD-GPT\\workplace\\5_29_news_data\\AA\\news_16\\places.txt', 'D:\\23spring\\AD-GPT\\workplace\\5_29_news_data\\AA\\news_17\\places.txt', 'D:\\23spring\\AD-GPT\\workplace\\5_29_news_data\\AA\\news_18\\places.txt', 'D:\\23spring\\AD-GPT\\workplace\\5_29_news_data\\AA\\news_19\\places.txt', 'D:\\23spring\\AD-GPT\\workplace\\5_29_news_data\\AA\\news_2\\places.txt', 'D:\\23spring\\AD-GPT\\workplace\\5_29_news_data\\AA\\news_20\\places.txt', 'D:\\23spri
# ...

# %%
places_all = []
for p in files:
    name = p.split('\\')[-3]
    with open(p, "r", encoding='utf8') as f:
        for places in f.readlines():
            places_all.append([places.replace('\n',''),name])
print(places_all)
# Out:
# [['Elizabeth', 'AA'], ['Colorado', 'AA'], ['Oklahoma', 'AA'], ['Wyoming', 'AA'], ['Oregon', 'AA'], ['Washington', 'AA'], ['Virginia', 'AA'], ['Michigan', 'AA'], ['Missouri', 'AA'], ['Texas', 'AA'], ['Columbia', 'AA'], ['Montana', 'AA'], ['New York', 'AA'], ['Delaware', 'AA'], ['Chicago', 'AA'], ['Kansas', 'AA'], ['Iowa', 'AA'], ['Florida', 'AA'], ['Maryland', 'AA'], ['Oklahoma', 'AA'], ['Colorado', 'AA'], ['Wyoming', 'AA'], ['Delaware', 'AA'], ['Virginia', 'AA'], ['Houston', 'AA'], ['Kansas', 'AA'], ['Maryland', 'AA'], ['Iowa', 'AA'], ['Chicago', 'AA'], ['New York', 'AA'], ['Oregon', 'AA'], ['Washington', 'AA'], ['Los Angeles', 'AA'], ['Michigan', 'AA'], ['Montana', 'AA'], ['Columbia', 'AA'], ['Missouri', 'AA'], ['University', 'AA'], ['Florida', 'AA'], ['Elizabeth', 'AA'], ['Ramon', 'AA'], ['Texas', 'AA'], ['Oklahoma', 'AA'], ['Colorado', 'AA'], ['Wyoming', 'AA'], ['Delaware', 'AA'], ['Virginia', 'AA'], ['Kansas', 'AA'], ['Maryland', 'AA'], ['Iowa', 'AA'], ['Chicago', 'AA'], ['New Yo
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import pandas as pd
import geopandas as gpd

from urllib import request
from geotext import GeoText

from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut

from shapely.geometry import Point, Polygon
import descartes
def get_city_info(save_path):
    places_all = []
    geolocator = Nominatim(user_agent="Icarus",timeout=2)
    for p in files:
        print(p)
        name = p.split('\\')[-3]
        with open(p, "r", encoding='utf8') as f:
            for places in f.readlines():
                location = geolocator.geocode(places)
                #print(location.latitude, location.longitude)
                places_all.append([places.replace('\n',''),name,location[0],(location.latitude, location.longitude)])
                # print(places_all)
    df = pd.DataFrame(places_all, columns=['City Name', 'News_Source','Country','Coordinates'])    
    df.to_csv(save_path+'/geo_information.csv',index=None)   
    geometry = [Point(x[1], x[0]) for x in df['Coordinates']]
    crs = {'init': 'epsg:4326'}
    geo_df = gpd.GeoDataFrame(df, crs=crs, geometry=geometry)
    pwd = os.getcwd()
    countries_map =gpd.read_file(pwd + '/world_map.shp')
    f, ax = plt.subplots(figsize=(16, 16))
    countries_map.plot(ax=ax, alpha=0.4, color='grey')
    geo_df.loc[geo_df['News_Source']=='AA','color'] = '#C62828'
    geo_df.loc[geo_df['News_Source']=='Mayo','color'] = '#283593'
    geo_df.loc[geo_df['News_Source']=='bbc','color'] = '#FF9800'
    geo_df.loc[geo_df['News_Source']=='NIA','color'] = '#82B0D2'
    cmap = ['#C62828','#283593','#FF9800','#283593']
    geo_df['geometry'].plot(ax=ax, markersize = 30,color =geo_df['color'],marker = '^', alpha=.5)
    font_dict = dict(fontsize =24, family = 'Times New Roman', style = 'italic')
    plt.title("Where Latest Alzheimer's Disease News Happen",fontdict= font_dict)
    # plt.legend(labels=["Alzheimer's Association","BBC","Mayo Clinic","NIA"], fontsize =10)
    plt.savefig(save_path + '/Places.jpg',dpi = 300)
# Out:
# D:\23spring\AD-GPT\workplace\5_29_news_data\AA\news_1\places.txt
# c:\Users\SEU\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\util\ssl_.py:260: DeprecationWarning: ssl.PROTOCOL_TLS is deprecated
#   context = SSLContext(ssl_version or PROTOCOL_TLS)
# c:\Users\SEU\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connection.py:407: DeprecationWarning: ssl.match_hostname() is deprecated
#   match_hostname(cert, asserted_hostname)
# D:\23spring\AD-GPT\workplace\5_29_news_data\AA\news_10\places.txt
# D:\23spring\AD-GPT\workplace\5_29_news_data\AA\news_11\places.txt
# D:\23spring\AD-GPT\workplace\5_29_news_data\AA\news_12\places.txt
# D:\23spring\AD-GPT\workplace\5_29_news_data\AA\news_13\places.txt
# D:\23spring\AD-GPT\workplace\5_29_news_data\AA\news_14\places.txt
# D:\23spring\AD-GPT\workplace\5_29_news_data\AA\news_15\places.txt
# D:\23spring\AD-GPT\workplace\5_29_news_data\AA\news_16\places.txt
# ...

# %%
# geo_df.save
# Out:
# c:\Users\SEU\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
import spacy
spacy.load('en_core_web_sm')
from spacy.lang.en import English
parser = English()
def tokenize(text):
    lda_tokens = []
    tokens = parser(text)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            lda_tokens.append('URL')
        elif token.orth_.startswith('@'):
            lda_tokens.append('SCREEN_NAME')
        else:
            lda_tokens.append(token.lower_)
    return lda_tokens

# %%
import nltk
nltk.download('wordnet')
from nltk.corpus import wordnet as wn
def get_lemma(word):
    lemma = wn.morphy(word)
    if lemma is None:
        return word
    else:
        return lemma
    
from nltk.stem.wordnet import WordNetLemmatizer
def get_lemma2(word):
    return WordNetLemmatizer().lemmatize(word)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\SEU\AppData\Roaming\nltk_data...

# %%
nltk.download('stopwords')
en_stop = set(nltk.corpus.stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\SEU\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
def prepare_text_for_lda(text):
    tokens = tokenize(text)
    tokens = [token for token in tokens if len(token) > 4]
    tokens = [token for token in tokens if token not in en_stop]
    tokens = [get_lemma(token) for token in tokens]
    return tokens

import random
text_data = []
with open('D:/23spring/AD-GPT/workplace/AA/news_1/summary.txt',"r", encoding='utf8') as f:
    text = f.read()
    print(text)
    tokens = prepare_text_for_lda(text)
    print(tokens)
    text_data.append(tokens)
# Out:
# The Alzheimer's Association welcomes the FDA approval of Rexulti for treating agitation associated with Alzheimer's disease, but emphasizes the importance of non-drug approaches and calls for access to treatments that address the underlying biology of the disease.
# ['alzheimer', 'association', 'welcome', 'approval', 'rexulti', 'treat', 'agitation', 'associate', 'alzheimer', 'disease', 'emphasize', 'importance', 'approach', 'call', 'access', 'treatment', 'address', 'underlie', 'biology', 'disease']

# %%
from gensim import corpora
dictionary = corpora.Dictionary(text_data)
corpus = [dictionary.doc2bow(text) for text in text_data]
import pickle
pickle.dump(corpus, open('corpus.pkl', 'wb'))
dictionary.save('dictionary.gensim')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[176], line 2
#       1 from gensim import corpora
# ----> 2 dictionary = corpora.Dictionary(text_data)
#       3 corpus = [dictionary.doc2bow(text) for text in text_data]
#       4 import pickle
#
# File c:\Users\SEU\AppData\Local\Programs\Python\Python311\Lib\site-packages\gensim\corpora\dictionary.py:78, in Dictionary.__init__(self, documents, prune_at)
#      75 self.num_nnz = 0
#      77 if documents is not None:
# ---> 78     self.add_documents(documents, prune_at=prune_at)
#      79     self.add_lifecycle_event(
#      80         "created",
#      81         msg=f"built {self} from {self.num_docs} documents (total {self.num_pos} corpus positions)",
#      82     )
#
# ...

# %%
import gensim
NUM_TOPICS = 5
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=15)
ldamodel.save('model5.gensim')
topics = ldamodel.print_topics(num_words=4)
for topic in topics:
    print(topic)
# Out:
# (0, '0.056*"alzheimer" + 0.056*"disease" + 0.056*"biology" + 0.056*"underlie"')
# (1, '0.056*"biology" + 0.056*"access" + 0.056*"agitation" + 0.056*"rexulti"')
# (2, '0.056*"disease" + 0.056*"alzheimer" + 0.056*"biology" + 0.056*"agitation"')
# (3, '0.056*"associate" + 0.056*"biology" + 0.056*"approval" + 0.056*"treat"')
# (4, '0.093*"alzheimer" + 0.093*"disease" + 0.051*"address" + 0.051*"association"')

# %%
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = 3, id2word=dictionary, passes=15)
ldamodel.save('model3.gensim')
topics = ldamodel.print_topics(num_words=4)
for topic in topics:
    print(topic)
# Out:
# (0, '0.056*"alzheimer" + 0.056*"disease" + 0.056*"underlie" + 0.056*"address"')
# (1, '0.056*"address" + 0.056*"disease" + 0.056*"alzheimer" + 0.056*"biology"')
# (2, '0.090*"disease" + 0.090*"alzheimer" + 0.051*"approach" + 0.051*"treatment"')

# %%
dictionary = gensim.corpora.Dictionary.load('dictionary.gensim')
corpus = pickle.load(open('corpus.pkl', 'rb'))
lda = gensim.models.ldamodel.LdaModel.load('model5.gensim')
import pyLDAvis.gensim
lda_display = pyLDAvis.gensim.prepare(lda, corpus, dictionary, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[78], line 5
#       3 lda = gensim.models.ldamodel.LdaModel.load('model5.gensim')
#       4 import pyLDAvis.gensim
# ----> 5 lda_display = pyLDAvis.gensim.prepare(lda, corpus, dictionary, sort_topics=False)
#       6 pyLDAvis.display(lda_display)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pyLDAvis\gensim.py:123, in prepare(topic_model, corpus, dictionary, doc_topic_dist, **kwargs)
#      78 """Transforms the Gensim TopicModel and related corpus and dictionary into
#      79 the data structures needed for the visualization.
#      80
#    (...)
#     120 See `pyLDAvis.prepare` for **kwargs.
#     121 """
#     122 opts = fp.merge(_extract_data(topic_model, corpus, dictionary, doc_topic_dist), kwargs)
# --> 123 return vis_prepare(**opts)
#
# ...

# %%
#importing libaries
import re, numpy as np, pandas as pd
from pprint import pprint

# Gensim
import gensim, spacy, logging, warnings
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use', 'not', 'would', 'say', 'could', '_', 'be', 'know', 
                   'good', 'go', 'get', 'do', 'done', 'try', 'many', 'some', 'nice', 'thank', 'think', 'see',
                   'rather', 'easy', 'easily', 'lot', 'lack', 'make', 'want', 'seem', 'run', 'need', 'even', 
                   'right', 'line', 'even', 'also', 'may', 'take', 'come'])

# %%
data_words = []
with open('D:/23spring/AD-GPT/workplace/AA/news_1/summary.txt',"r", encoding='utf8') as f:
    text = f.read()
    print(text)
    tokens = prepare_text_for_lda(text)
    print(tokens)
    data_words.append(tokens)
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)
# Out:
# The Alzheimer's Association welcomes the FDA approval of Rexulti for treating agitation associated with Alzheimer's disease, but emphasizes the importance of non-drug approaches and calls for access to treatments that address the underlying biology of the disease.
# ['alzheimer', 'association', 'welcome', 'approval', 'rexulti', 'treat', 'agitation', 'associate', 'alzheimer', 'disease', 'emphasize', 'importance', 'approach', 'call', 'access', 'treatment', 'address', 'underlie', 'biology', 'disease']

# %%
def process_words(texts, stop_words=stop_words, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """Remove Stopwords, Form Bigrams, Trigrams and Lemmatization"""
    texts = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]
    texts = [bigram_mod[doc] for doc in texts]
    texts = [trigram_mod[bigram_mod[doc]] for doc in texts]
    texts_out = []
    nlp = spacy.load("en_core_web_sm")
    #nlp = spacy.load('en', disable=['parser', 'ner'])
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    # remove stopwords once more after lemmatization
    texts_out = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts_out]    
    return texts_out

data_ready = process_words(data_words)  # processed Text Data!

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_ready)

# Create Corpus: Term Document Frequency
corpus = [id2word.doc2bow(text) for text in data_ready]

# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=4, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=10,
                                           passes=10,
                                           alpha='symmetric',
                                           iterations=100,
                                           per_word_topics=True)

pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.101*"disease" + 0.056*"rexulti" + 0.056*"underlie" + 0.056*"approach" + '
#   '0.056*"call" + 0.056*"treat" + 0.056*"address" + 0.056*"agitation" + '
#   '0.056*"approval" + 0.056*"alzheimer"'),
#  (1,
#   '0.059*"access" + 0.059*"emphasize" + 0.059*"biology" + 0.059*"alzheimer" + '
#   '0.059*"treatment" + 0.059*"importance" + 0.059*"agitation" + '
#   '0.059*"associate" + 0.059*"welcome" + 0.059*"approval"'),
#  (2,
#   '0.059*"associate" + 0.059*"access" + 0.059*"welcome" + 0.059*"importance" + '
#   '0.059*"alzheimer" + 0.059*"approval" + 0.059*"call" + 0.059*"address" + '
#   '0.059*"agitation" + 0.059*"treatment"'),
#  (3,
#   '0.059*"welcome" + 0.059*"disease" + 0.059*"access" + 0.059*"importance" + '
#   '0.059*"treatment" + 0.059*"treat" + 0.059*"associate" + 0.059*"biology" + '
#   '0.059*"emphasize" + 0.059*"address"')]

# %%
def format_topics_sentences(ldamodel=None, corpus=corpus, texts = []):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=data_ready)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic.head(5)
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0               0              0.9603
#
#                                             Keywords  \
# 0  disease, rexulti, underlie, approach, call, tr...
#
#                                                 Text
# 0  [welcome, approval, rexulti, treat, agitation,...

# %%
from matplotlib import pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import matplotlib.colors as mcolors
cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

cloud = WordCloud(stopwords=stop_words,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=10,
                  colormap='tab10',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

topics = lda_model.show_topics(formatted=False)

fig, axes = plt.subplots(2, 2, figsize=(10,10), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=16))
    plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[87], line 2
#       1 from matplotlib import pyplot as plt
# ----> 2 from wordcloud import WordCloud, STOPWORDS
#       3 import matplotlib.colors as mcolors
#       4 cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
from collections import Counter
import matplotlib.colors as mcolors
topics = lda_model.show_topics(formatted=False)
data_flat = [w for w_list in data_ready for w in w_list]
counter = Counter(data_flat)

out = []
for i, topic in topics:
    for word, weight in topic:
        out.append([word, i , weight, counter[word]])

df = pd.DataFrame(out, columns=['word', 'topic_id', 'importance', 'word_count'])        

# Plot Word Count and Weights of Topic Keywords
fig, axes = plt.subplots(2, 2, figsize=(16,10), sharey=True, dpi=160)
cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]
for i, ax in enumerate(axes.flatten()):
    ax.bar(x='word', height="word_count", data=df.loc[df.topic_id==i, :], color=cols[i], width=0.5, alpha=0.3, label='Word Count')
    ax_twin = ax.twinx()
    ax_twin.bar(x='word', height="importance", data=df.loc[df.topic_id==i, :], color=cols[i], width=0.2, label='Weights')
    ax.set_ylabel('Word Count', color=cols[i])
    ax_twin.set_ylim(0, 0.030); ax.set_ylim(0, 3500)
    ax.set_title('Topics of News in the past '+str(i+1)+' weeks: ' + str(i), color=cols[i], fontdict =font_dict)
    ax.tick_params(axis='y', left=False)
    ax.set_xticklabels(df.loc[df.topic_id==i, 'word'], rotation=30, horizontalalignment= 'right')
    ax.legend(loc='upper left'); ax_twin.legend(loc='upper right')

fig.tight_layout(w_pad=2)    
fig.suptitle('Word Count and Importance of Topic Keywords', fontsize=22, y=1.05)    
plt.show()

# %%
from datetime import datetime
import datetime
dte1 = 'May 11, 2023'
dte3 = 'Apr 14, 2023'
dte2 = datetime.datetime.strptime(dte1, '%b %d, %Y')
dte4 = datetime.datetime.strptime(dte3, '%b %d, %Y')
print(dte4)
# def change_date
now = datetime.datetime.now()
print(now)
print((dte4-now).days)
# Out:
# 2023-04-14 00:00:00
# 2023-05-27 22:48:40.195544
# -44

# %%
import datetime
def get_time_difference(date_txt,news_type='bbc')->int: 
    time_now = datetime.datetime.now()
    date_desired = []
    if news_type == 'bbc' or news_type == 'NIA':
        date_desired = datetime.datetime.strptime(date_txt, '%Y-%m-%d')
    if news_type == 'AA' or news_type == 'Mayo':
        date_desired = datetime.datetime.strptime(date_txt, '%B %d, %Y')
    day_difference = (time_now-date_desired).days
    if day_difference>=0:
        return day_difference
    else:
        return 0

# %%
files = find_files('D:\\23spring\\AD-GPT\\workplace\\','dates')
re_l = np.zeros(4)
for date_f in files:
    with open(date_f, "r", encoding='utf8') as f:
         date_txt = f.readline().replace('\n','')
         news_type = date_f.split('\\')[-3]
    day_difference = get_time_difference(date_txt,news_type)
    if(day_difference<=30):
        re_l[0]+=1
    if day_difference>30 and day_difference<=60:
        re_l[1]+=1
    if day_difference>60 and day_difference<=180:
        re_l[2]+=1    
    if day_difference>180 :
        re_l[3]+=1     
X= np.arange(4)
plt.bar(2.4*X,re_l, color = '#63b2ee', linewidth = 1.5, width=1)
plt.xticks(ticks=2.4*X,labels=['last month','last two months', 'last six months', 'more than six months' ])
plt.title('The number of relevant news that happened in the past period',fontdict=font_dict)
plt.show()

# %%
import pandas as pd
list_news = []
for i in range(0,12):
    list_news.append(str())
list_news[0] =list_news[0] +'1'
list_news
# Out:
# ['1', '', '', '', '', '', '', '', '', '', '', '']

# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import os
def get_time_difference(date_txt,news_type='bbc')->int: 
    time_now = datetime.datetime.now()
    date_desired = []
    if news_type == 'bbc' or news_type == 'NIA':
        date_desired = datetime.datetime.strptime(date_txt, '%Y-%m-%d')
    if news_type == 'AA' or news_type == 'Mayo':
        print(len(date_txt.split("-")))
        if(len(date_txt.split("-"))<=1):
            
            date_desired = datetime.datetime.strptime(date_txt, '%B %d, %Y')
        else:
            date_desired = datetime.datetime.strptime(date_txt, '%Y-%m-%d')
    # if news_type == 'Mayo':
    #     date_desired = datetime.datetime.strptime(date_txt, '%b. %d, %Y')
    day_difference = (time_now-date_desired).days
    if day_difference>=0:
        return day_difference
    else:
        return 0
def find_files(path, A):
    results = []
    for root, _, files in os.walk(path):
        for name in files:
            if name == A+'.txt':
                results.append(os.path.join(root,name))
    return results

def get_summary_period(path_dir):
    result = [] 
    # text_month = str()
    # text_2month = str()
    # text_6month = str()
    # text_12month = str()
    files = find_files(path_dir,'dates')
    month_num = 12
    re_l = np.zeros(month_num)    
    list_text_month = []
    X_label = []
    for i in range(0,month_num):
        list_text_month.append(str())
        X_label.append(str(i+1))
    for date_f in files:        
        with open(date_f, "r", encoding='utf8') as f:
            print(date_f)
            date_txt = f.readline().replace('\n','')
            news_type = date_f.split('\\')[-3]
        summary_f = date_f.replace('dates','summary')
        with open(summary_f, "r", encoding='utf8') as f:
            summary_txt = f.readline().replace('\n','')
        day_difference = get_time_difference(date_txt,news_type)
        time_index = int(day_difference/30)
        if time_index >=month_num:
            time_index = month_num-1
        re_l[time_index]+=1
        list_text_month[time_index] = list_text_month[time_index] + summary_txt
        # if(day_difference<=30):
        #     re_l[0]+=1
        #     text_month = text_month +' '+summary_txt
        # if day_difference>30 and day_difference<=60:
        #     re_l[1]+=1
        #     text_2month = text_2month +' '+summary_txt
        # if day_difference>60 and day_difference<=180:
        #     re_l[2]+=1   
        #     text_6month = text_6month +' '+summary_txt
        # if day_difference>180 :
        #     re_l[3]+=1  
        #     text_12month = text_12month +' '+summary_txt
    X= np.arange(month_num)
    
    plt.figure(figsize=(12,10))
    plt.bar(2.4*X,re_l, color = '#63b2ee', linewidth = 1.5, width=1)
    X1 = ['2023-5','2023-4','2023-3','2023-2','2023-1','2022-12','2022-11','2022-10','2022-9','2022-8','2022-7','2022-6']
    plt.xticks(ticks=2.4*X, labels=X1, rotation = 30, fontsize =20 )
    plt.xlabel('Timeline (month)',fontsize =20 )
    plt.ylabel('News Count',fontsize =20 )
    plt.title('The Number of Relevant News that Happened in the Past Period',fontdict=dict(fontsize =24, family = 'Times New Roman', style = 'italic'))
    plt.savefig(path_dir+'news_count1.jpg', dpi = 300)
    plt.close()
    result = list_text_month
    return result

# %%
from matplotlib import rcParams
# config = {
#     "font.family":'Times New Roman',  # 设置字体类型
#     # "font.size": 20,
# #     "mathtext.fontset":'stix',
# }
# rcParams.update(config)
path_dir = 'D:\\23spring\\AD-GPT\\workplace\\'
font_dict = dict(fontsize =24, family = 'Times New Roman', style = 'italic')
result = get_summary_period(path_dir)
result[0]
# Out:
# D:\23spring\AD-GPT\workplace\AA\news_1\dates.txt
# 1
# D:\23spring\AD-GPT\workplace\AA\news_10\dates.txt
# 1
# D:\23spring\AD-GPT\workplace\AA\news_100\dates.txt
# 3
# D:\23spring\AD-GPT\workplace\AA\news_101\dates.txt
# 3
# D:\23spring\AD-GPT\workplace\AA\news_102\dates.txt
# 3
# D:\23spring\AD-GPT\workplace\AA\news_103\dates.txt
# 3
# D:\23spring\AD-GPT\workplace\AA\news_104\dates.txt
# 3
# D:\23spring\AD-GPT\workplace\AA\news_105\dates.txt
# 3
# D:\23spring\AD-GPT\workplace\AA\news_106\dates.txt
# 3
# D:\23spring\AD-GPT\workplace\AA\news_107\dates.txt
# 1
# D:\23spring\AD-GPT\workplace\AA\news_108\dates.txt
# 1
# D:\23spring\AD-GPT\workplace\AA\news_109\dates.txt
# 1
# D:\23spring\AD-GPT\workplace\AA\news_11\dates.txt
# 1
# D:\23spring\AD-GPT\workplace\AA\news_110\dates.txt
# 1
# D:\23spring\AD-GPT\workplace\AA\news_111\dates.txt
# 1
# D:\23spring\AD-GPT\workplace\AA\news_112\dates.txt
# 1
# D:\23spring\AD-GPT\workplace\AA\news_113\dates.txt
# 1
# ...

# %%
import spacy
import pandas as pd
import nltk
import gensim
from nltk.corpus import wordnet as wn
from nltk.stem.wordnet import WordNetLemmatizer
from spacy.lang.en import English
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim import corpora
import matplotlib.colors as mcolors
import matplotlib as mpl
import matplotlib.pyplot as plt
import pyLDAvis.gensim
from matplotlib import rcParams
config = {
    "font.family":'Times New Roman',  # 设置字体类型
    "font.size": 20,
#     "mathtext.fontset":'stix',
}
rcParams.update(config)

spacy.load('en_core_web_sm')

from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use', 'not', 'would', 'say', 'could', '_', 'be', 'know', 
                   'good', 'go', 'get', 'do', 'done', 'try', 'many', 'some', 'nice', 'thank', 'think', 'see',
                   'rather', 'easy', 'easily', 'lot', 'lack', 'make', 'want', 'seem', 'run', 'need', 'even', 
                   'right', 'line', 'even', 'also', 'may', 'take', 'come'])

def process_words(texts, stop_words=stop_words, allowed_postags=['NOUN']): ##'VERB', 'ADJ', , 'ADV'
    """Remove Stopwords, Form Bigrams, Trigrams and Lemmatization"""
    texts = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]
    texts = [bigram_mod[doc] for doc in texts]
    texts = [trigram_mod[bigram_mod[doc]] for doc in texts]
    texts_out = []
    nlp = spacy.load("en_core_web_sm")
    #nlp = spacy.load('en', disable=['parser', 'ner'])
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    # remove stopwords once more after lemmatization
    texts_out = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts_out]    
    return texts_out

def get_lemma(word):
    lemma = wn.morphy(word)
    if lemma is None:
        return word
    else:
        return lemma
    

def get_lemma2(word):
    return WordNetLemmatizer().lemmatize(word)
en_stop = set(nltk.corpus.stopwords.words('english'))

parser = English()
def tokenize(text):
    lda_tokens = []
    tokens = parser(text)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            lda_tokens.append('URL')
        elif token.orth_.startswith('@'):
            lda_tokens.append('SCREEN_NAME')
        else:
            lda_tokens.append(token.lower_)
    return lda_tokens

def prepare_text_for_lda(text):
    tokens = tokenize(text)
    tokens = [token for token in tokens if len(token) > 4]
    tokens = [token for token in tokens if token not in en_stop]
    tokens = [get_lemma(token) for token in tokens]
    return tokens

K = []
for i in range(12):
    K.append(str(i+1)+'_Month_Keywords')
    
topic_num_all = [4,3,3,4,3,3,3,3,3,3,4,4]
topic_num_AA = [4,4,3,4,4,4,4,4,3,4,3,3] 
topic_num_bbc = [4,3,3,4,4,3,4,3,3,4,3,3]
topic_num_NIA = [4,4,4,3,3,3,4,3,3,4,3,3]
df_final = []
for text_data, k,topic_num in zip(result, K, topic_num_NIA):
    if len(text_data)>0:
        data_words  = prepare_text_for_lda(text_data)
        print(data_words)
        
        # Build the bigram and trigram models
        bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
        trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  
        bigram_mod = gensim.models.phrases.Phraser(bigram)
        trigram_mod = gensim.models.phrases.Phraser(trigram)
        data_ready = process_words(data_words)  # processed Text Data!
        # Create Dictionary
        id2word = corpora.Dictionary(data_ready)

        # Create Corpus: Term Document Frequency
        corpus = [id2word.doc2bow(text) for text in data_ready]

        # Build LDA model
        lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                                id2word=id2word,
                                                num_topics=topic_num, 
                                                random_state=100,
                                                update_every=1,
                                                chunksize=10,
                                                passes=10,
                                                alpha='symmetric',
                                                iterations=100,
                                                per_word_topics=True)

        # pprint(lda_model.print_topics())
        # df_topic_sents_keywords = format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=data_ready)
        # df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
        # print(df_dominant_topic.head(5))
        from collections import Counter
        topics = lda_model.show_topics(formatted=False)
        data_flat = [w for w_list in data_ready for w in w_list]
        counter = Counter(data_flat)

        out = []
        for i, topic in topics:
            for word, weight in topic:
                out.append([word, i , weight, counter[word]])

        df = pd.DataFrame(out, columns=['word', 'topic_id', 'importance', 'word_count'])        

        # Plot Word Count and Weights of Topic Keywords
        # fig, axes = plt.subplots(2, 2, figsize=(16,10), sharey=True, dpi=300)
        # cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]
        # for i, ax in enumerate(axes.flatten()):
        #     ax.bar(x='word', height="word_count", data=df.loc[df.topic_id==i, :], color=cols[i], width=0.5, alpha=0.3, label='Word Count')
        #     ax_twin = ax.twinx()
        #     ax_twin.bar(x='word', height="importance", data=df.loc[df.topic_id==i, :], color=cols[i], width=0.2, label='Weights')
        #     ax.set_ylabel('Word Count', color=cols[i])
        #     # ax_twin.set_ylim(0, 0.030); ax.set_ylim(0, 100)
        #     ax.set_title('Topic: ' + str(i), color=cols[i], fontsize=16)
        #     ax.tick_params(axis='y', left=False)
        #     ax.set_xticklabels(df.loc[df.topic_id==i, 'word'], rotation=30, horizontalalignment= 'right')
        #     ax.legend(loc='upper left'); ax_twin.legend(loc='upper right')

        # fig.tight_layout(w_pad=2)    
        # font_dict = dict(size =32, family = 'Times New Roman', style = 'italic')
        # fig_title = 'Word Count and Importance of Topic Keywords in News of the Period of '+k.replace('_',' ')
        # fig.suptitle(fig_title, fontdict= font_dict,y =1.05)    
        # plt.savefig('D:\\23spring\\AD-GPT\\workplace\\'+fig_title.replace(' ','_')+'.jpg',dpi=300, bbox_inches="tight") ## 
        # plt.close()
        topic_words ={}
        for i in range(0,topic_num):
            topic_words.update(dict(topics[i][1]))
        print(topic_words)
        np.save('D:\\23spring\\AD-GPT\\workplace\\topic_words_in_'+k+'.npy',topic_words)
        df['Time'] = k
        # df.to_csv('D:\\23spring\\AD-GPT\\workplace\\topic_words_in_'+k+'.csv', index =None)
        df_final.append(df)
        pyLDAvis.enable_notebook()
        vis = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary=lda_model.id2word)
        pyLDAvis.save_html(vis, 'D:\\23spring\\AD-GPT\\workplace\\topic_words_in_'+k+'.html')
    
        # import pyLDAvis.gensim
        # pyLDAvis.enable_notebook()
        # vis = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary=lda_model.id2word)
        # vis
        # print(1)
    # import json
    # # dumps 将数据转换成字符串
    # info_json = json.dumps(topic_words,sort_keys=False, indent=4, separators=(',', ': '))
    # # 显示数据类型
    # print(type(info_json))
    # f1 = open('D:\\23spring\\AD-GPT\\workplace\\topic_words_in_'+k.replace(' ','_')+'.json', 'w')
    # f1.write(info_json)
df_result = pd.concat(df_final)
df_result.to_csv('D:\\23spring\\AD-GPT\\workplace\\Topics_Trend_All.csv', index =None)
# Out:
# ['research', 'conduct', 'potential', 'benefit', 'music', 'healthy', 'aging', 'include', 'effects', 'memory', 'emotion', 'brain', 'study', 'conduct', 'music', 'reduce', 'patient', 'delirium', 'soothe', 'sleep', 'people', 'living', 'dementia', 'reduce', 'agitation', 'aggression', 'music', 'revive', 'learning', 'memory', 'function', 'older', 'adult', 'memory', 'impairment', 'enhance', 'social', 'network', 'reduce', 'isolation', 'loneliness', 'study', 'explore', 'potential', 'therapeutic', 'benefit', 'music', 'include', 'singing', 'choir', 'listening', 'carefully', 'sequence', 'music', 'research', 'need', 'understand', 'cognitive', 'social', 'psychological', 'mechanism', 'music', 'impact', 'health', 'study', 'fund', 'national', 'institute', 'aging', 'found', 'remove', 'neuron', 'reduce', 'pathological', 'hallmark', 'alzheimer', 'disease', 'study', 'suggest', 'activity', 'neuron', 'promote', 'development', 'alzheimer', 'research', 'provide', 'insight', 'potential', 'therapeutic', 'target'
# ...

# %%
# topic_words = np.load('D:\\23spring\\AD-GPT\\workplace\\topic_words_in_One_Month.npy', allow_pickle=True).item()
# topic_words
import pandas as pd
fff = pd.read_csv('D:/23spring/AD-GPT/workplace/topic_words_in_1_month_keywords.csv')
fff['Time'] = '1 month'
fff
# Out:
#            word  topic_id  importance  word_count     Time
# 0        system         0    0.106004           2  1 month
# 1        myelin         0    0.089815           5  1 month
# 2       decline         0    0.078069           6  1 month
# 3    university         0    0.049200           1  1 month
# 4       profile         0    0.049192           1  1 month
# 5     cognition         0    0.039731           3  1 month
# 6         music         0    0.036494           6  1 month
# 7   participant         0    0.036150           2  1 month
# 8        future         0    0.027751           2  1 month
# 9        memory         0    0.016974           3  1 month
# 10    alzheimer         1    0.130941          26  1 month
# 11        brain         1    0.123143          10  1 month
# 12    longevity         1    0.068984           1  1 month
# 13       sample         1    0.068965           1  1 month
# 14        adult         1    0.059820           3  1 month
# ...

# %%
topic_words ={}
for i in range(0,4):
    topic_words.update(dict(topics[i][1]))
print(topic_words)
# Out:
# {'hour': 0.0721856, 'leadership': 0.06927764, 'role': 0.06927271, 'activity': 0.06927219, 'group': 0.051921416, 'total': 0.03762699, 'reduction': 0.03762616, 'business': 0.022639282, 'segment': 0.02120817, 'communication': 0.021208065, 'career': 0.07498665, 'champion': 0.07498647, 'inclusion': 0.074986085, 'scientist': 0.07498354, 'physician': 0.07498276, 'alzheimer': 0.037859403, 'researcher': 0.032423202, 'month': 0.032422625, 'effect': 0.032422427, 'condition': 0.032421924, 'diversity': 0.23627092, 'bernard': 0.10160999, 'disease': 0.050174277, 'chief': 0.043187335, 'officer': 0.04318553, 'adult': 0.02737306, 'base': 0.027369685, 'frequency': 0.023707042, 'recruitment': 0.017857864, 'increase': 0.015854696, 'research': 0.11353588, 'equity': 0.05855131, 'effort': 0.05855002, 'inclusiveness': 0.058549892, 'health': 0.058546, 'vegetable': 0.05736629, 'migraine': 0.057366244, 'intensity': 0.027660523, 'paper': 0.023668444, 'trial': 0.019710092}

# %%
import spacy
import pandas as pd
import nltk
import gensim
from nltk.corpus import wordnet as wn
from nltk.stem.wordnet import WordNetLemmatizer
from spacy.lang.en import English
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim import corpora
import matplotlib.colors as mcolors
import matplotlib as mpl
import matplotlib.pyplot as plt

from matplotlib import rcParams
config = {
    "font.family":'Times New Roman',  # 设置字体类型
    "font.size": 20,
#     "mathtext.fontset":'stix',
}
rcParams.update(config)

spacy.load('en_core_web_sm')

from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use', 'not', 'would', 'say', 'could', '_', 'be', 'know', 
                   'good', 'go', 'get', 'do', 'done', 'try', 'many', 'some', 'nice', 'thank', 'think', 'see',
                   'rather', 'easy', 'easily', 'lot', 'lack', 'make', 'want', 'seem', 'run', 'need', 'even', 
                   'right', 'line', 'even', 'also', 'may', 'take', 'come'])

def process_words(texts, stop_words=stop_words, allowed_postags=['NOUN']): ##'VERB', 'ADJ', , 'ADV'
    """Remove Stopwords, Form Bigrams, Trigrams and Lemmatization"""
    texts = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]
    texts = [bigram_mod[doc] for doc in texts]
    texts = [trigram_mod[bigram_mod[doc]] for doc in texts]
    texts_out = []
    nlp = spacy.load("en_core_web_sm")
    #nlp = spacy.load('en', disable=['parser', 'ner'])
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    # remove stopwords once more after lemmatization
    texts_out = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts_out]    
    return texts_out

def get_lemma(word):
    lemma = wn.morphy(word)
    if lemma is None:
        return word
    else:
        return lemma
    

def get_lemma2(word):
    return WordNetLemmatizer().lemmatize(word)
en_stop = set(nltk.corpus.stopwords.words('english'))

parser = English()
def tokenize(text):
    lda_tokens = []
    tokens = parser(text)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            lda_tokens.append('URL')
        elif token.orth_.startswith('@'):
            lda_tokens.append('SCREEN_NAME')
        else:
            lda_tokens.append(token.lower_)
    return lda_tokens

def prepare_text_for_lda(text):
    tokens = tokenize(text)
    tokens = [token for token in tokens if len(token) > 4]
    tokens = [token for token in tokens if token not in en_stop]
    tokens = [get_lemma(token) for token in tokens]
    return tokens

# %%
re_all = str()
for re_t in result:
    re_all = re_all + re_t
re_all
# Out:
# 'The Alzheimer\'s Association and Early Stage Advisory Group have urged the FDA to recommend traditional approval of Leqembi for the treatment of Alzheimer\'s disease. Leqembi was granted accelerated approval in January 2023 and Phase 3 data showed it met primary and key secondary endpoints with highly statistically significant results. The FDA will complete its review for traditional approval by July 6, 2023.The Alzheimer\'s Association welcomes the FDA approval of Rexulti for the treatment of agitation associated with Alzheimer\'s disease, but still advocates for non-drug approaches and access to treatments that address the underlying biology of the disease.Alzheimer\'s advocate Tony Gonzales testified before the House Ways and Means Health Subcommittee, advocating for CMS coverage for FDA-approved Alzheimer\'s treatments. Bipartisan members of the subcommittee expressed their support for Gonzales and their desire for CMS to change its policy. There is mounting bipartisan political
# ...

# %%
data_words  = prepare_text_for_lda(re_all)
print(data_words)
num_topics_1 = 5
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)
data_ready = process_words(data_words)  # processed Text Data!
# Create Dictionary
id2word = corpora.Dictionary(data_ready)

# Create Corpus: Term Document Frequency
corpus = [id2word.doc2bow(text) for text in data_ready]

# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                        id2word=id2word,
                                        num_topics=num_topics_1, 
                                        random_state=100,
                                        update_every=1,
                                        chunksize=10,
                                        passes=10,
                                        alpha='symmetric',
                                        iterations=100,
                                        per_word_topics=True)

# pprint(lda_model.print_topics())
# df_topic_sents_keywords = format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=data_ready)
# df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
# print(df_dominant_topic.head(5))
from collections import Counter
topics = lda_model.show_topics(formatted=False)
data_flat = [w for w_list in data_ready for w in w_list]
counter = Counter(data_flat)

out = []
for i, topic in topics:
    for word, weight in topic:
        out.append([word, i , weight, counter[word]])

df = pd.DataFrame(out, columns=['word', 'topic_id', 'importance', 'word_count'])        

# Plot Word Count and Weights of Topic Keywords
# fig, axes = plt.subplots(2, 2, figsize=(16,10), sharey=True, dpi=300)
# cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]
# for i, ax in enumerate(axes.flatten()):
#     ax.bar(x='word', height="word_count", data=df.loc[df.topic_id==i, :], color=cols[i], width=0.5, alpha=0.3, label='Word Count')
#     ax_twin = ax.twinx()
#     ax_twin.bar(x='word', height="importance", data=df.loc[df.topic_id==i, :], color=cols[i], width=0.2, label='Weights')
#     ax.set_ylabel('Word Count', color=cols[i])
#     # ax_twin.set_ylim(0, 0.030); ax.set_ylim(0, 100)
#     ax.set_title('Topic: ' + str(i), color=cols[i], fontsize=16)
#     ax.tick_params(axis='y', left=False)
#     ax.set_xticklabels(df.loc[df.topic_id==i, 'word'], rotation=30, horizontalalignment= 'right')
#     ax.legend(loc='upper left'); ax_twin.legend(loc='upper right')

# fig.tight_layout(w_pad=2)    
# font_dict = dict(size =32, family = 'Times New Roman', style = 'italic')
# fig_title = 'Word Count and Importance of Topic Keywords in News of the Period of '+k.replace('_',' ')
# fig.suptitle(fig_title, fontdict= font_dict,y =1.05)    
# plt.savefig('D:\\23spring\\AD-GPT\\workplace\\'+fig_title.replace(' ','_')+'.jpg',dpi=300, bbox_inches="tight") ## 
# plt.close()
topic_words ={}
for i in range(0,num_topics_1):
    topic_words.update(dict(topics[i][1]))
print(topic_words)
# np.save('D:\\23spring\\AD-GPT\\workplace\\topic_words_in_'+k+'.npy',topic_words)
df.to_csv('D:\\23spring\\AD-GPT\\workplace\\topic_words_in_all_text.csv', index =None)
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary=lda_model.id2word)
# pyLDAvis.save_html(vis, 'D:\\23spring\\AD-GPT\\workplace\\1.html')
pyLDAvis.save_html(vis,'D:\\23spring\\AD-GPT\\workplace\\1.html')
# plt.savefig('D:\\23spring\\AD-GPT\\workplace\\1.jpg')
print(1)
vis
# Out:
# ['alzheimer', 'association', 'early', 'stage', 'advisory', 'group', 'urge', 'recommend', 'traditional', 'approval', 'leqembi', 'treatment', 'alzheimer', 'disease', 'leqembi', 'grant', 'accelerate', 'approval', 'january', 'phase', 'show', 'primary', 'secondary', 'endpoint', 'highly', 'statistically', 'significant', 'result', 'complete', 'review', 'traditional', 'approval', '2023.the', 'alzheimer', 'association', 'welcome', 'approval', 'rexulti', 'treatment', 'agitation', 'associate', 'alzheimer', 'disease', 'still', 'advocate', 'approach', 'access', 'treatment', 'address', 'underlie', 'biology', 'disease', 'alzheimer', 'advocate', 'gonzales', 'testify', 'house', 'means', 'health', 'subcommittee', 'advocate', 'coverage', 'approve', 'alzheimer', 'treatment', 'bipartisan', 'member', 'subcommittee', 'express', 'support', 'gonzales', 'desire', 'change', 'policy', 'mounting', 'bipartisan', 'political', 'support', 'change', 'policy', 'alzheimer', 'association', 'improve', 'online', 'resource
# ...

# %%
Topics_words_all =[]
color_all = []
Topic_words_t1 = ['alzheimer','protein','lifestyle','lipid','drug']
color1 = ['#FF9292','#FFB4B4','#FFDCDC','#FFE8E8','#FFF8EA']
Topic_words_t2 = ['level','diagnosis','accord','caregiver','vitamin']
color2 = ['#48466D','#BE9FE1','#C9B6E4','#E1CCEC','#F1F1F6']
Topic_words_t3 = ['disease','individual','amyloid','treatment','tissue']
color3 = ['#52734D','#91C788','#DCEDC1','#DDFFBC','#FEFFDE']
Topic_words_t4 = ['disorder','increase','people','future','structure']
color4 = ['#142850','#27496D','#0C7B93','#00A8CC','#C8D9EB']
Topic_words_t5 = ['brain','sleep','cell','blodd','resource']
color5 = ['#402218','#AA4A30','#D57149','#E89F71','#EDCFA9']
Topics_words_all = Topic_words_t1+Topic_words_t2+Topic_words_t3+Topic_words_t4+Topic_words_t5
color_all = color1 + color2 + color3 + color4 + color5
Topics_words_all
# color_all
# Out:
# ['alzheimer',
#  'protein',
#  'lifestyle',
#  'lipid',
#  'drug',
#  'level',
#  'diagnosis',
#  'accord',
#  'caregiver',
#  'vitamin',
#  'disease',
#  'individual',
#  'amyloid',
#  'treatment',
#  'tissue',
#  'disorder',
#  'increase',
#  'people',
#  'future',
#  'structure',
#  'brain',
#  'sleep',
#  'cell',
#  'blodd',
#  'resource']

# %%
topic_num_all = [4,3,3,4,3,3,3,3,3,3,4,4]
topic_num_AA = [4,4,3,4,4,4,4,4,3,4,3,3] 
topic_num_bbc = [4,3,3,4,4,3,4,3,3,4,3,3]
topic_num_NIA = [4,4,4,3,3,3,4,3,3,4,3,3]
# topic_num_all
# Out:
# [4, 3, 3, 4, 3, 3, 3, 3, 3, 3, 4, 4]

# %%
import matplotlib.pyplot as plt
from datetime import date
import numpy as np
 
# %matplotlib inline  # since I'm doing this work in a Jupyter Notebook
dates = [date(2023, 5, 26), date(2023, 4, 26), date(2022, 12, 31), date(2022, 6, 1)]
min_date = date(np.min(dates).year, np.min(dates).month-2, np.min(dates).day)
max_date = date(np.max(dates).year, np.max(dates).month+1, np.max(dates).day)
 
labels = ['Last Month', 'Last Two Months', 'Last Half Year', 
          'Last Year']
# labels with associated dates  
labels = ['{0:%d %b %Y}:\n{1}'.format(d, l) for l, d in zip (labels, dates)]
fig, ax = plt.subplots(figsize=(15, 4), constrained_layout=True)
_ = ax.set_ylim(-2, 5)
_ = ax.set_xlim(min_date, max_date)
_ = ax.axhline(0, xmin=0.05, xmax=0.95, c='deeppink', zorder=1)
 
_ = ax.scatter(dates, np.zeros(len(dates)), s=120, c='palevioletred', zorder=2)
_ = ax.scatter(dates, np.zeros(len(dates)), s=30, c='darkmagenta', zorder=3)
label_offsets = np.zeros(len(dates))
label_offsets[::2] = 0.35
label_offsets[1::2] = -1
for i, (l, d) in enumerate(zip(labels, dates)):
    _ = ax.text(d, label_offsets[i], l, ha='center', fontfamily='serif', fontweight='bold', color='royalblue',fontsize=12)
stems = np.zeros(len(dates))
stems[::2] = 0.3
stems[1::2] = -0.3   
markerline, stemline, baseline = ax.stem(dates, stems, use_line_collection=True)
_ = plt.setp(markerline, marker=',', color='darkmagenta')
_ = plt.setp(stemline, color='darkmagenta')
# hide lines around chart
for spine in ["left", "top", "right", "bottom"]:
    _ = ax.spines[spine].set_visible(False)
 
# hide tick labels
_ = ax.set_xticks([])
_ = ax.set_yticks([])
 
_ = ax.set_title("Changes in keywords for Alzheimer's disease over the past year", fontweight="bold", fontfamily='serif', fontsize=16, 
                 color='royalblue')
plt.savefig('D:\\23spring\\AD-GPT\\workplace\\timeline.jpg',dpi=300)
# Out:
# C:\Users\SEU\AppData\Local\Temp\ipykernel_20712\3177853755.py:29: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   markerline, stemline, baseline = ax.stem(dates, stems, use_line_collection=True)

# %%
# 1. Wordcloud of Top N words in each topic
from matplotlib import pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import matplotlib.colors as mcolors

cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

cloud = WordCloud(stopwords=stop_words,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=10,
                  colormap='tab10',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

topics = lda_model.show_topics(formatted=False)

fig, axes = plt.subplots(2, 2, figsize=(10,10), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=16))
    plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 # 1. Wordcloud of Top N words in each topic
#       2 from matplotlib import pyplot as plt
# ----> 3 from wordcloud import WordCloud, STOPWORDS
#       4 import matplotlib.colors as mcolors
#       6 cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
news_path = 'D:/23spring/AD-GPT/workplace/AA/'
from datetime import date, timedelta
newslist = os.listdir(news_path)
count=0
for news in newslist:
    count = int(news.split('_')[1])
    if(not (os.path.exists(news_path+news+'/dates.txt'))):
        print(news)
        # time_now = datetime.datetime.now()
        date_desired1 = (date.today()-timedelta(days=int(365*count/140)))
        print(date_desired1.strftime('%B %d, %Y'))
        with open(news_path+news+"/dates.txt", "w", encoding='utf8') as f:
            f.writelines(str(date_desired1)+'\n')
# Out:
# news_102
# September 07, 2022
# news_103
# September 04, 2022
# news_104
# September 01, 2022
# news_105
# August 30, 2022
# news_106
# August 27, 2022
# news_114
# August 06, 2022
# news_115
# August 04, 2022
# news_116
# August 01, 2022
# news_117
# July 29, 2022
# news_118
# July 27, 2022
# news_119
# July 24, 2022
# news_120
# July 22, 2022
# news_121
# July 19, 2022
# news_122
# July 16, 2022
# news_124
# July 11, 2022
# news_126
# July 06, 2022
# news_127
# July 03, 2022
# news_128
# July 01, 2022
# news_129
# June 28, 2022
# news_131
# June 23, 2022
# news_132
# June 20, 2022
# news_133
# June 18, 2022
# news_134
# June 15, 2022
# news_135
# June 13, 2022
# news_136
# June 10, 2022
# news_137
# June 07, 2022
# news_138
# June 05, 2022
# news_65
# December 12, 2022
# news_66
# December 09, 2022
# news_67
# December 07, 2022
# news_68
# December 04, 2022
# news_69
# December 02, 2022
# news_70
# November 29, 2022
# news_71
# November 26, 2022
# news_72
# November 24, 2022
# ...

# %%
time_now = datetime.datetime.now().strftime('%B %d, %Y')
time_now
from datetime import date, timedelta
time_now = date(2023, 5, 26)
time_now = time_now.day-30
time_now
current_date = date.today().isoformat()   
days_before = (date.today()-timedelta(days=30))
days_after = (date.today()+timedelta(days=30)) 
days_before.strftime('%B %d, %Y')
# Out:
# 'April 30, 2023'

# %%
## Time graph

import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
def gaussian_smooth(x, y, grid, sd):
    weights = np.transpose([stats.norm.pdf(grid, m, sd) for m in x])
    weights = weights / weights.sum(0)
    return (weights * y).sum(1)
x = np.arange(1990, 2020) # (N,) array-like

y = [np.random.randint(0, 5, size=30) for _ in range(5)] # (M, N) array-like
fig, ax = plt.subplots(figsize=(10, 7))
grid = np.linspace(1985, 2025, num=500)
y_smoothed = [gaussian_smooth(x, y_, grid, 1) for y_ in y]
ax.stackplot(grid, y_smoothed, baseline="sym");
# fig, ax = plt.subplots(figsize=(10, 7))
# ax.stackplot(x, y)
# ax.stackplot(x, y, baseline="sym")
# ax.axhline(0, color="black", ls="--")

y
# grid
# Out:
# [array([1, 4, 0, 4, 2, 0, 4, 0, 2, 3, 1, 2, 3, 4, 3, 0, 1, 2, 2, 0, 2, 0,
#         3, 2, 0, 4, 3, 4, 4, 2]),
#  array([0, 3, 3, 3, 4, 0, 3, 1, 4, 3, 3, 3, 2, 3, 1, 3, 4, 1, 2, 2, 2, 0,
#         4, 0, 1, 3, 2, 1, 2, 4]),
#  array([4, 1, 0, 2, 2, 3, 2, 4, 1, 3, 0, 2, 2, 3, 2, 0, 1, 0, 4, 3, 1, 3,
#         3, 1, 2, 0, 1, 4, 2, 0]),
#  array([2, 3, 2, 3, 1, 3, 2, 4, 2, 4, 2, 1, 1, 3, 3, 4, 2, 0, 0, 0, 0, 1,
#         1, 1, 2, 2, 2, 0, 3, 2]),
#  array([4, 4, 0, 4, 1, 4, 2, 3, 0, 4, 4, 2, 3, 1, 1, 4, 2, 3, 4, 1, 2, 2,
#         4, 4, 0, 4, 4, 4, 0, 4])]

# %%
import pandas as pd 
Topics = pd.read_csv('D:/23spring/AD-GPT实验记录/5_30_news_data/data_for_topic_trend/Topics_Trend_All.csv')
Topics_words = []
for i in range(len(Topics)):
    if(Topics['word'][i] not in Topics_words and Topics['word_count'][i]>7):
        Topics_words.append(Topics['word'][i])
len(Topics_words)
Topics_words
# Out:
# ['alzheimer',
#  'brain',
#  'disease',
#  'treatment',
#  'research',
#  'increase',
#  'resource',
#  'support',
#  'association',
#  'people',
#  'health',
#  'adult',
#  'funding',
#  'individual',
#  'decline',
#  'memory',
#  'trial',
#  'researcher',
#  'cell',
#  'diagnosis']

# %%
Topics_words_all =[]
color_all = []
Topic_words_t1 = ['alzheimer','protein','lifestyle','lipid','drug']
color1 = ['#FF9292','#FFB4B4','#FFDCDC','#FFE8E8','#FFF8EA']
color1 = ['#FF55BB']
Topic_words_t2 = ['level','diagnosis','accord','caregiver','vitamin']
color2 = ['#48466D','#BE9FE1','#C9B6E4','#E1CCEC','#F1F1F6']
color2 = ['#FFD3A3']
Topic_words_t3 = ['disease','individual','amyloid','treatment','tissue']
color3 = ['#52734D','#91C788','#DCEDC1','#DDFFBC','#FEFFDE']
color3 = ['#FCFFB2']
Topic_words_t4 = ['disorder','increase','people','future','structure']
color4 = ['#142850','#27496D','#0C7B93','#00A8CC','#C8D9EB']
color4 = ['#B6EAFA']
Topic_words_t5 = ['brain','sleep','cell','blood','resource']
color5 = ['#402218','#AA4A30','#D57149','#E89F71','#EDCFA9']
color5 = ['#A0D8B3']
Topics_words_all = Topic_words_t1+Topic_words_t2+Topic_words_t3+Topic_words_t4+Topic_words_t5
color_all = 5*color1 + 5*color2 + 5*color3 + 5*color4 + 5*color5
Topics_words_all
# color_all
timegraph_y = []
timegraph_y1 = []
for i in range(len(Topics_words_all)):
    timegraph_y.append(np.zeros(12))
    timegraph_y1.append(np.zeros(12))
Topics_words_all
# Topics_words.index('research')
# Out:
# ['alzheimer',
#  'protein',
#  'lifestyle',
#  'lipid',
#  'drug',
#  'level',
#  'diagnosis',
#  'accord',
#  'caregiver',
#  'vitamin',
#  'disease',
#  'individual',
#  'amyloid',
#  'treatment',
#  'tissue',
#  'disorder',
#  'increase',
#  'people',
#  'future',
#  'structure',
#  'brain',
#  'sleep',
#  'cell',
#  'blodd',
#  'resource']

# %%
# myclors = ['#63b2ee','#76da91','#f8cb7f','#f89588','#7cd6cf','#9192ab','#7898e1','#efa666','#eddd86','#9987ce','#FFF7D4','#76da91','#A1A9D0','#F0988C','#B70404','#9E9E9E','#CFEAF1','#C4A5DE','#F6CAE5','#96CCCB']


# timegraph_y1
# myclors = ['#63b2ee','#76da91','#f8cb7f','#f89588','#7cd6cf','#9192ab','#7898e1','#efa666','#eddd86','#9987ce','#FFF7D4','#76da91','#A1A9D0','#F0988C','#B70404','#9E9E9E','#CFEAF1','#C4A5DE','#F6CAE5','#96CCCB']
timegraph_y = []
timegraph_y1 = []
for i in range(len(Topics_words_all)):
    timegraph_y.append(np.zeros(12))
    timegraph_y1.append(np.zeros(12))
for i in range(len(Topics)):
    if(Topics['word'][i] in Topics_words_all):
        x_k = Topics_words_all.index(Topics['word'][i])
        y_k = int(Topics['Time'][i].split('_')[0])-1
        timegraph_y[x_k][y_k] = timegraph_y[x_k][y_k] + Topics['word_count'][i]
        timegraph_y1[x_k][y_k] = timegraph_y1[x_k][y_k] + Topics['importance'][i]

x = np.arange(0, 12) # (N,) array-like

y = timegraph_y
fig, ax = plt.subplots(figsize=(18, 15))
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
grid = np.linspace(-3, 16, num=500)
y_smoothed = [gaussian_smooth(x, y_, grid, 1) for y_ in y]
ax.stackplot(grid, y_smoothed,labels=Topics_words_all,baseline="sym",colors= color_all);
plt.legend(loc='upper left',fontsize = 23,ncol = 5,frameon=False)#,bbox_to_anchor=(0, 0.5, 0.5, 0.5)
# X1 = np.arange(1, 13)
X1 = ['2023-5','2023-4','2023-3','2023-2','2023-1','2022-12','2022-11','2022-10','2022-9','2022-8','2022-7','2022-6']
plt.xticks(ticks=np.arange(1,13), labels=X1,fontsize = 24,rotation =30)
plt.yticks(fontsize = 24)
plt.xlabel('Timeline (month)',fontsize = 28)
plt.ylabel('Word Count',fontsize = 28)
plt.xlim(1,12)
plt.ylim(-2,3)
plt.title("Topics Trend of Alzheimer's Disease in the Last Year",fontdict={'fontsize': 32, 'family': 'Times New Roman', 'style': 'italic'})
plt.savefig("D:/23spring/AD-GPT实验记录/5_30_news_data/Topics_Trend_All_word_count1.jpg",dpi=600)

y = timegraph_y1
fig, ax = plt.subplots(figsize=(18, 15))
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
grid = np.linspace(-1, 13, num=500)
y_smoothed = [gaussian_smooth(x, y_, grid, 1) for y_ in y]
ax.stackplot(grid, y_smoothed,labels=Topics_words_all,baseline="sym",colors= color_all);
plt.legend(loc='upper center',fontsize = 23,ncol = 5,frameon=False)#,bbox_to_anchor=(0, 0.5, 0.5, 0.5)
# X1 = np.arange(1, 13)
X1 = ['2023-5','2023-4','2023-3','2023-2','2023-1','2022-12','2022-11','2022-10','2022-9','2022-8','2022-7','2022-6']
plt.xticks(ticks=np.arange(1,13), labels=X1,fontsize = 24,rotation =30)
plt.yticks(fontsize = 24)
plt.xlabel('Timeline (month)',fontsize = 28)
plt.ylabel('Word Importance (%)',fontsize = 28)
plt.xlim(1,12)
plt.ylim(-0.010,0.015)
plt.title("Topics Trend of Alzheimer's Disease in the Last Year",fontdict={'fontsize': 32, 'family': 'Times New Roman', 'style': 'italic'})
plt.savefig("D:/23spring/AD-GPT实验记录/5_30_news_data/Topics_Trend_All_word_importance1.jpg",dpi=600)

# %%
font_dict
c = ['1']
5*c
import imgkit
path_wk = r'C:\Program Files\wkhtmltopdf\bin\wkhtmltoimage.exe'
config = imgkit.config(wkhtmltoimage=path_wk)
options = {
    'zoom': 4,
    # 'width': 1920*2, 
    # 'height': 1080*2,
    'quality': 100
}
imgkit.from_url('D:\\23spring\\AD-GPT\\workplace\\1.html', 'D:\\23spring\\AD-GPT\\workplace\\lda.jpg',config = config, options = options)
# Out:
# Loading page (1/2)
# Rendering (2/2)
# Done
# True

# %%
from duckduckgo_search import ddg
re = ddg('alzheimer', max_results=20)
re
# Out:
# c:\Users\SEU\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\util\ssl_.py:260: DeprecationWarning: ssl.PROTOCOL_TLS is deprecated
#   context = SSLContext(ssl_version or PROTOCOL_TLS)
# c:\Users\SEU\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connection.py:407: DeprecationWarning: ssl.match_hostname() is deprecated
#   match_hostname(cert, asserted_hostname)
# c:\Users\SEU\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\util\ssl_.py:260: DeprecationWarning: ssl.PROTOCOL_TLS is deprecated
#   context = SSLContext(ssl_version or PROTOCOL_TLS)
# c:\Users\SEU\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connection.py:407: DeprecationWarning: ssl.match_hostname() is deprecated
#   match_hostname(cert, asserted_hostname)

# %%
from langchain.llms import GPT4All
model = GPT4All(model = 'ggml-gpt4all-l13b-snoozy.bin')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 from langchain.llms import GPT4All
# ----> 2 model = GPT4All(model = 'ggml-gpt4all-l13b-snoozy.bin')
#
# File c:\Users\SEU\AppData\Local\Programs\Python\Python311\Lib\site-packages\pydantic\main.py:339, in pydantic.main.BaseModel.__init__()
#
# File c:\Users\SEU\AppData\Local\Programs\Python\Python311\Lib\site-packages\pydantic\main.py:1102, in pydantic.main.validate_model()
#
# File c:\Users\SEU\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\llms\gpt4all.py:169, in GPT4All.validate_environment(cls, values)
#     162         raise ValueError(f"Incorrect gpt4all backend {cls.backend}")
#     164     model_kwargs = {
#     165         k: v
#     166         for k, v in values.items()
#     167         if k in GPT4All._model_param_names(backend)
#     168     }
# ...

# %%
# from duckduckgo_search import ddg
# re = ddg("alzheimer's disease", max_results=20)
# print(re)


import requests
from bs4 import BeautifulSoup

# 输入要搜索的关键字和要保存的文件名
# keyword = input("请输入搜索关键字: ")
# filename = input("请输入要保存的文件名: ")
keyword = "Alzheimer's disease"
# 创建Google搜索URL
google_url = f'https://www.google.com/search?q={keyword}'

# 发送HTTP请求
response = requests.get(google_url)
print(response)
# 使用BeautifulSoup库解析HTML内容
soup = BeautifulSoup(response.text, 'html.parser')
print(soup)
# 查找包含搜索结果的HTML元素
search_results = soup.find_all('div', class_='r')

search_results
# Out:
# <Response [429]>
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">
#
# <html>
# <head><meta content="text/html; charset=utf-8" http-equiv="content-type"/><meta content="initial-scale=1" name="viewport"/><title>https://www.google.com/search?q=Alzheimer's%20disease</title></head>
# <body onload="e=document.getElementById('captcha');if(e){e.focus();} if(solveSimpleChallenge) {solveSimpleChallenge(,);}" style="font-family: arial, sans-serif; background-color: #fff; color: #000; padding:20px; font-size:18px;">
# <div style="max-width:400px;">
# <hr noshade="" size="1" style="color:#ccc; background-color:#ccc;"/><br/>
# <form action="index" id="captcha-form" method="post">
# <noscript>
# <div style="font-size:13px;">
#   In order to continue, please enable javascript on your web browser.
# </div>
# </noscript>
# <script async="" defer="" src="https://www.google.com/recaptcha/api.js"></script>
# ...

# %%
# re = Topics[Topics['topic_id']==0]
# import numpy as np
# np.sort(re['word_count'])[]
Topics_words_all =[]
for i in range(5):
    to_tt =[]
    to_tmp = Topics[Topics['topic_id']==i]
    tmp = to_tmp.sort_values('word_count', ascending=False)
    print(tmp)
    for j in range(5):
        to_tt.append(tmp.iloc[j][0])
    Topics_words_all = Topics_words_all + to_tt

Topics_words_all
# Out:
#            word  topic_id  importance  word_count               Time
# 261   alzheimer         0    0.045890          64   9_Month_Keywords
# 326   alzheimer         0    0.043600          34  11_Month_Keywords
# 267    research         0    0.020655          27   9_Month_Keywords
# 232     disease         0    0.056918          26   8_Month_Keywords
# 201     disease         0    0.095439          23   7_Month_Keywords
# ..          ...       ...         ...         ...                ...
# 295     address         0    0.037340           1  10_Month_Keywords
# 297  inequality         0    0.037321           1  10_Month_Keywords
# 100     measure         0    0.123978           1   4_Month_Keywords
# 79      protein         0    0.028661           1   3_Month_Keywords
# 296     vaccine         0    0.037334           1  10_Month_Keywords
#
# [120 rows x 5 columns]
#             word  topic_id  importance  word_count              Time
# ...
